# %% [markdown]
# # Kronos Fine-tuning Pipeline
#
# This notebook handles the end-to-end fine-tuning of the Kronos model on NIFTY 50 data.

# %%
# Step 0: Clone the repository and move files to working directory
import os
if not os.path.exists('prepare_nifty50_noklib.py'):
    # !git clone https://github.com/ayan1-git/Kronos_finetune.git temp_repo
    # !cp -r temp_repo/* ./
    # !rm -rf temp_repo
    print("Repository cloned and files moved to working directory.")
else:
    print("Files already present.")
# Out:
# Cloning into 'temp_repo'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 50 (delta 7), reused 48 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 16.49 MiB | 21.78 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# Repository cloned and files moved to working directory.

# %%
# !pip install -q transformers

# %%
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")
# Out:
# GPU Available: True
# GPU Device: Tesla T4

# %%
# Step 1: Prepare the Dataset
# !python prepare_nifty50_noklib.py
# Out:
# train: 20 symbols saved
# val: 20 symbols saved
# test: 20 symbols saved

# %%
# Step 2: Train Tokenizer
# !torchrun --standalone --nproc_per_node=1 train_tokenizer.py
# Out:
# [W511 07:45:23.512181068 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# Traceback (most recent call last):
#   File "/kaggle/working/train_tokenizer.py", line 15, in <module>
#     import comet_ml
# ModuleNotFoundError: No module named 'comet_ml'
# E0511 07:45:27.254000 155 torch/distributed/elastic/multiprocessing/api.py:984] failed (exitcode: 1) local_rank: 0 (pid: 163) of binary: /usr/bin/python3
# Traceback (most recent call last):
#   File "/usr/local/bin/torchrun", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/elastic/multiprocessing/errors/__init__.py", line 362, in wrapper
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/run.py", line 991, in main
#     run(args)
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/run.py", line 982, in run
# ...

# %%
# Step 3: Train Predictor
# !torchrun --standalone --nproc_per_node=1 train_predictor.py
