# %% [markdown]
# # Kronos Fine-tuning Pipeline
#
# This notebook handles the end-to-end fine-tuning of the Kronos model on NIFTY 50 data.

# %%
# Step 0: Ensure we have the latest code from GitHub
import os, shutil
if os.path.exists('temp_repo'):
    shutil.rmtree('temp_repo')

# !git clone https://github.com/ayan1-git/Kronos_finetune.git temp_repo
# !cp -rf temp_repo/* ./
# !rm -rf temp_repo
print("Latest code pulled from GitHub.")
# Out:
# Cloning into 'temp_repo'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 72 (delta 21), reused 65 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (72/72), 16.54 MiB | 23.55 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# Latest code pulled from GitHub.

# %%
# Step 1: Install Dependencies
# !pip install -q transformers

# %%
# Step 2: GPU Check
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
print(f"GPU Count: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    print(f"GPU {i}: {torch.cuda.get_device_name(i)}")

# %%
# Step 3: Prepare the Dataset
# !python prepare_nifty50_noklib.py

# %%
# Step 4: Train Tokenizer
# Using 2 GPUs for DDP training
# !torchrun --standalone --nproc_per_node=2 train_tokenizer.py

# %%
# Step 5: Train Predictor
# Using 2 GPUs for DDP training
# !torchrun --standalone --nproc_per_node=2 train_predictor.py
# Out:
# W0511 09:10:30.768000 1682 torch/distributed/run.py:852]
# W0511 09:10:30.768000 1682 torch/distributed/run.py:852] *****************************************
# W0511 09:10:30.768000 1682 torch/distributed/run.py:852] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0511 09:10:30.768000 1682 torch/distributed/run.py:852] *****************************************
# [W511 09:10:31.052994399 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W511 09:10:33.552578263 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W511 09:10:33.633696110 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [DDP Setup] Global Rank: 1/2, Local Rank (GPU): 1 on device 1
# [DDP Setup] Global Rank: 0/2, Local Rank (GPU): 0 on device 0
# ...
