# %% [markdown]
# # Kronos Fine-tuning Pipeline
#
# This notebook handles the end-to-end fine-tuning of the Kronos model on NIFTY 50 data.

# %%
# Step 0: Ensure we have the latest code
import os, shutil

# Force fresh clone to get latest changes from GitHub
if os.path.exists('temp_repo'):
    shutil.rmtree('temp_repo')

# !git clone https://github.com/ayan1-git/Kronos_finetune.git temp_repo

# Copy all files including subdirectories (model, utils, etc.)
# !cp -rf temp_repo/* ./
# !rm -rf temp_repo

print("Latest code pulled from GitHub.")

# %%
# !pip install -q transformers

# %%
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")

# %%
# Step 1: Prepare the Dataset
# !python prepare_nifty50_noklib.py

# %%
# Step 2: Train Tokenizer
# !torchrun --standalone --nproc_per_node=1 train_tokenizer.py

# %%
# Step 3: Train Predictor
# !torchrun --standalone --nproc_per_node=1 train_predictor.py
